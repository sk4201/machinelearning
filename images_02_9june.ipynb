# %% [markdown]
# <a href="https://colab.research.google.com/github/sk4201/machinelearning/blob/Supervised/images_02_9june.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## COMPUTER VISION

# %%
import cv2

import matplotlib.pyplot as plt

# %%
# checking version
#print(cv2._version_ _)

# %%
# image reading
img=cv2.imread("uv.jpg",1)
img1=cv2.imread("uv.jpg",0)
img2=cv2.imread("uv.jpg",-1)

# 1 means image  in same color channel --GRB OR RGB
# 0 means no color channel --Black & white -- GRAY image
# -1 maintain image transperancy
print(img)
# Out:
# [[[ 68 121 178]
#   [ 69 124 181]
#   [ 71 128 184]
#   ...
#   [  7  11  22]
#   [  7  11  22]
#   [  7  11  22]]
#
#  [[ 70 123 180]
#   [ 71 126 183]
#   [ 73 130 186]
#   ...
#   [  7  11  22]
#   [  7  11  22]
#   [  7  11  22]]
#
#  [[ 73 125 185]
#   [ 74 128 188]
#   [ 75 131 190]
#   ...
#   [  7  11  22]
#   [  7  11  22]
#   [  7  11  22]]
#
#  ...
#
#  [[197 212 231]
#   [198 213 232]
#   [198 213 232]
#   ...
#   [ 39 131 210]
#   [ 39 131 210]
#   [ 39 131 210]]
#
#  [[193 208 227]
#   [194 209 228]
#   [195 210 229]
#   ...
#   [ 38 130 209]
#   [ 37 129 208]
#   [ 37 129 208]]
#
#  [[193 208 227]
#   [194 209 228]
#   [195 210 229]
#   ...
#   [ 38 130 209]
#   [ 37 129 208]
#   [ 37 129 208]]]

# %%
# print shape
print(img.shape)
# Out:
# (330, 600, 3)

# %%
#type
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
# to display image
plt.imshow(img)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
plt.imshow(img[0:300,0:300])

# %%
# wait for window to close
cv2.waitKey(0)
