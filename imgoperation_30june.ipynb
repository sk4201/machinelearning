# %% [markdown]
# <a href="https://colab.research.google.com/github/sk4201/machinelearning/blob/computervision/imgoperation_30june.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMAGE OPERATION

# %%
import sys 
import cv2
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
# image name as first argu
dog = sys.argv[1]

# %%
# image read
img = cv2.imread('dog.jpg',1)   # loading image in a colored format -- original image
img
# Out:
# array([[[201, 198, 190],
#         [201, 198, 190],
#         [203, 200, 192],
#         ...,
#         [104, 151, 148],
#         [104, 151, 148],
#         [103, 150, 147]],
#
#        [[206, 203, 195],
#         [206, 203, 195],
#         [208, 205, 197],
#         ...,
#         [106, 153, 150],
#         [106, 153, 150],
#         [105, 152, 149]],
#
#        [[212, 209, 201],
#         [213, 210, 202],
#         [214, 211, 203],
#         ...,
#         [107, 157, 153],
#         [109, 156, 153],
#         [106, 156, 152]],
#
#        ...,
#
#        [[149, 145, 140],
#         [146, 142, 137],
#         [142, 139, 135],
#         ...,
#         [174, 166, 166],
#         [174, 166, 166],
#         [173, 165, 165]],
#
#        [[146, 142, 137],
#         [142, 138, 133],
#         [137, 134, 130],
#         ...,
#         [173, 165, 165],
#         [173, 165, 165],
#         [172, 164, 164]],
#
#        [[136, 132, 127],
#         [132, 128, 123],
#         [127, 124, 120],
# ...

# %%
cv2_imshow(img)
cv2_imshow(img-50)
cv2_imshow(img+100)
# Out:
# <PIL.Image.Image image mode=RGB size=537x597 at 0x7FE6EA0206D8>
# <PIL.Image.Image image mode=RGB size=537x597 at 0x7FE6EA0208D0>
# <PIL.Image.Image image mode=RGB size=537x597 at 0x7FE6EA0207F0>

# %%
# saving image
+cv2.imwrite('new.jpg',img)
# Out:
# True
