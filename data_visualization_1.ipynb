# %% [markdown]
# <a href="https://colab.research.google.com/github/sk4201/machinelearning/blob/master/data_visualization_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
visualize data graphs  
i)  take input from  a file where you have 4 rows and 5 columns
ii)  columns having - student_name , marks , age , contact , study_hours
iii)  visualize this data as pie chart
iv)  file name must  student.csv with all column separated by ','
'''
    
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('student.csv') #loading the file
print(df)
# Out:
#             Name  Marks  Age  Contact Number  Study_hours
# 0         sambha     50   14      7014865991            5
# 1  Arsene Wenger     60   15      9304939596            3
# 2     Friar Tuck     70   16      8587916498            4
# 3    Little John     55   13      8271681291            6
# 4  Sam Allardyce     65   11      8004435694            9
# 5  Dimi Berbatov     66   12      7277749291            7

# %%
plt.pie(df.Marks ,labels=df.Name, shadow=True ,autopct='%1.1f%%')
plt.grid(color='green')

plt.show()
